# %% [markdown]
# # VAE Training

# %% [markdown]
# ## imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from models.VAE import VariationalAutoencoder
from utils.loaders import load_mnist

# %%
# run params
SECTION = 'vae'
RUN_ID = '0002'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

mode =  'build' #'load' #

# %% [markdown]
# ## data

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()

# %% [markdown]
# ## architecture

# %%
vae = VariationalAutoencoder(
    input_dim = (28,28,1)
    , encoder_conv_filters = [32,64,64,64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    , z_dim = 2
    , r_loss_factor = 1000
)

if mode == 'build':
    vae.save(RUN_FOLDER)
else:
    vae.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
vae.encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# encoder_conv_0 (Conv2D)         (None, 28, 28, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 28, 28, 32)   0           encoder_conv_0[0][0]
# __________________________________________________________________________________________________
# encoder_conv_1 (Conv2D)         (None, 14, 14, 64)   18496       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 14, 14, 64)   0           encoder_conv_1[0][0]
# __________________________________________________________________________________________________
# encoder_conv_2 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 7, 7, 64)     0           encoder_conv_2[0][0]
# __________________________________________________________________________________________________
# encoder_conv_3 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 7, 7, 64)     0           encoder_conv_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3136)         0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# mu (Dense)                      (None, 2)            6274        flatten[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 2)            6274        flatten[0][0]
# __________________________________________________________________________________________________
# encoder_output (Sampling)       (None, 2)            0           mu[0][0]
#                                                                  log_var[0][0]
# ==================================================================================================
# Total params: 105,220
# Trainable params: 105,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
vae.decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 2)]               0
# _________________________________________________________________
# dense (Dense)                (None, 3136)              9408
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_0 (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_1 (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# decoder_conv_t_2 (Conv2DTran (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# decoder_conv_t_3 (Conv2DTran (None, 28, 28, 1)         289
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## training

# %%
LEARNING_RATE = 0.0005

# %%
vae.compile(LEARNING_RATE)

# %%
BATCH_SIZE = 32
EPOCHS = 50
PRINT_EVERY_N_BATCHES = 100
INITIAL_EPOCH = 0

# %%
vae.train(     
    x_train
    , batch_size = BATCH_SIZE
    , epochs = EPOCHS
    , run_folder = RUN_FOLDER
    , print_every_n_batches = PRINT_EVERY_N_BATCHES
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# Epoch 1/50
#    2/1875 [..............................] - ETA: 6:35 - loss: 231.9114 - reconstruction_loss: 231.9103 - kl_loss: 0.0011       WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0044s vs `on_train_batch_end` time: 0.0368s). Check your callbacks.
# 1875/1875 [==============================] - 19s 8ms/step - loss: 59.0616 - reconstruction_loss: 55.8562 - kl_loss: 3.2054
#
# Epoch 00001: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00001: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 2/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 51.9861 - reconstruction_loss: 48.1261 - kl_loss: 3.8600
#
# Epoch 00002: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00002: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 3/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 50.6725 - reconstruction_loss: 46.5587 - kl_loss: 4.1138
#
# Epoch 00003: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00003: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 4/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 49.8654 - reconstruction_loss: 45.5747 - kl_loss: 4.2907
#
# Epoch 00004: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00004: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 5/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 49.1905 - reconstruction_loss: 44.7691 - kl_loss: 4.4214
#
# Epoch 00005: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00005: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 6/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 48.6721 - reconstruction_loss: 44.1454 - kl_loss: 4.5268
#
# Epoch 00006: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00006: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 7/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 48.2929 - reconstruction_loss: 43.6874 - kl_loss: 4.6055
#
# Epoch 00007: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00007: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 8/50
# 1875/1875 [==============================] - 16s 8ms/step - loss: 47.9767 - reconstruction_loss: 43.3038 - kl_loss: 4.6729
#
# Epoch 00008: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00008: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 9/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 47.7391 - reconstruction_loss: 43.0036 - kl_loss: 4.7355
#
# Epoch 00009: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00009: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 10/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 47.4970 - reconstruction_loss: 42.7204 - kl_loss: 4.7766
#
# Epoch 00010: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00010: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 11/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 47.2878 - reconstruction_loss: 42.4941 - kl_loss: 4.7937
#
# Epoch 00011: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00011: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 12/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 47.1173 - reconstruction_loss: 42.2676 - kl_loss: 4.8497
#
# Epoch 00012: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00012: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 13/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 46.9708 - reconstruction_loss: 42.1011 - kl_loss: 4.8698
#
# Epoch 00013: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00013: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 14/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 46.8607 - reconstruction_loss: 41.9524 - kl_loss: 4.9083
#
# Epoch 00014: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00014: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 15/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 46.7173 - reconstruction_loss: 41.7910 - kl_loss: 4.9263
#
# Epoch 00015: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00015: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 16/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 46.5492 - reconstruction_loss: 41.6118 - kl_loss: 4.9373
#
# Epoch 00016: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00016: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 17/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 46.4942 - reconstruction_loss: 41.5130 - kl_loss: 4.9812
#
# Epoch 00017: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00017: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 18/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 46.3871 - reconstruction_loss: 41.3983 - kl_loss: 4.9888
#
# Epoch 00018: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00018: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 19/50
# 1875/1875 [==============================] - 17s 9ms/step - loss: 46.2666 - reconstruction_loss: 41.2745 - kl_loss: 4.9921
#
# Epoch 00019: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00019: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 20/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 46.2068 - reconstruction_loss: 41.1771 - kl_loss: 5.0297
#
# Epoch 00020: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00020: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 21/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 46.0914 - reconstruction_loss: 41.0641 - kl_loss: 5.0273
#
# Epoch 00021: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00021: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 22/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 46.0293 - reconstruction_loss: 40.9729 - kl_loss: 5.0564
#
# Epoch 00022: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00022: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 23/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 45.9365 - reconstruction_loss: 40.8799 - kl_loss: 5.0566
#
# Epoch 00023: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00023: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 24/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 45.8648 - reconstruction_loss: 40.7875 - kl_loss: 5.0773
#
# Epoch 00024: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00024: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 25/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 45.7985 - reconstruction_loss: 40.7273 - kl_loss: 5.0712
#
# Epoch 00025: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00025: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 26/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 45.7497 - reconstruction_loss: 40.6527 - kl_loss: 5.0970
#
# Epoch 00026: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00026: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 27/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 45.7029 - reconstruction_loss: 40.5846 - kl_loss: 5.1183
#
# Epoch 00027: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00027: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 28/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 45.6107 - reconstruction_loss: 40.4755 - kl_loss: 5.1352
#
# Epoch 00028: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00028: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 29/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 45.5443 - reconstruction_loss: 40.4023 - kl_loss: 5.1420
#
# Epoch 00029: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00029: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 30/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 45.5110 - reconstruction_loss: 40.3645 - kl_loss: 5.1465
#
# Epoch 00030: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00030: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 31/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 45.4240 - reconstruction_loss: 40.2666 - kl_loss: 5.1574
#
# Epoch 00031: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00031: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 32/50
# 1875/1875 [==============================] - 17s 9ms/step - loss: 45.4380 - reconstruction_loss: 40.2597 - kl_loss: 5.1783
#
# Epoch 00032: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00032: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 33/50
# 1875/1875 [==============================] - 18s 9ms/step - loss: 45.3396 - reconstruction_loss: 40.1562 - kl_loss: 5.1834
#
# Epoch 00033: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00033: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 34/50
# 1875/1875 [==============================] - 18s 9ms/step - loss: 45.3600 - reconstruction_loss: 40.1720 - kl_loss: 5.1881
#
# Epoch 00034: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00034: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 35/50
# 1875/1875 [==============================] - 18s 9ms/step - loss: 45.2681 - reconstruction_loss: 40.0675 - kl_loss: 5.2006
#
# Epoch 00035: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00035: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 36/50
# 1875/1875 [==============================] - 17s 9ms/step - loss: 45.2522 - reconstruction_loss: 40.0404 - kl_loss: 5.2118
#
# Epoch 00036: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00036: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 37/50
# 1875/1875 [==============================] - 18s 9ms/step - loss: 45.1717 - reconstruction_loss: 39.9597 - kl_loss: 5.2120: 1s - loss: 45.1570 - reconstruction_los
#
# Epoch 00037: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00037: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 38/50
# 1875/1875 [==============================] - 18s 9ms/step - loss: 45.1322 - reconstruction_loss: 39.8981 - kl_loss: 5.2341
#
# Epoch 00038: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00038: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 39/50
# 1875/1875 [==============================] - 18s 9ms/step - loss: 45.0851 - reconstruction_loss: 39.8560 - kl_loss: 5.2291
#
# Epoch 00039: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00039: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 40/50
# 1875/1875 [==============================] - 18s 9ms/step - loss: 45.0851 - reconstruction_loss: 39.8441 - kl_loss: 5.2410
#
# Epoch 00040: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00040: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 41/50
# 1875/1875 [==============================] - 18s 9ms/step - loss: 44.9977 - reconstruction_loss: 39.7550 - kl_loss: 5.2427
#
# Epoch 00041: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00041: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 42/50
# 1875/1875 [==============================] - 17s 9ms/step - loss: 44.9767 - reconstruction_loss: 39.7260 - kl_loss: 5.2507
#
# Epoch 00042: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00042: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 43/50
# 1875/1875 [==============================] - 17s 9ms/step - loss: 44.9429 - reconstruction_loss: 39.6873 - kl_loss: 5.2556
#
# Epoch 00043: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00043: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 44/50
# 1875/1875 [==============================] - 17s 9ms/step - loss: 44.8950 - reconstruction_loss: 39.6223 - kl_loss: 5.2727
#
# Epoch 00044: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00044: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 45/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 44.8747 - reconstruction_loss: 39.6026 - kl_loss: 5.2721
#
# Epoch 00045: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00045: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 46/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 44.8858 - reconstruction_loss: 39.6148 - kl_loss: 5.2710
#
# Epoch 00046: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00046: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 47/50
# 1875/1875 [==============================] - 17s 9ms/step - loss: 44.8312 - reconstruction_loss: 39.5511 - kl_loss: 5.2801
#
# Epoch 00047: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00047: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 48/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 44.7998 - reconstruction_loss: 39.5182 - kl_loss: 5.2816
#
# Epoch 00048: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00048: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 49/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 44.7912 - reconstruction_loss: 39.4956 - kl_loss: 5.2956
#
# Epoch 00049: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00049: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 50/50
# 1875/1875 [==============================] - 17s 9ms/step - loss: 44.7780 - reconstruction_loss: 39.4770 - kl_loss: 5.3010
#
# Epoch 00050: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00050: saving model to run/vae/0002_digits\weights\weights.h5
