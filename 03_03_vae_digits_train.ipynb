# %% [markdown]
# # VAE Training

# %% [markdown]
# ## imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from models.VAE import VariationalAutoencoder
from utils.loaders import load_mnist

# %%
# run params
SECTION = 'vae'
RUN_ID = '0002'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

mode =  'build' #'load' #

# %% [markdown]
# ## data

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()

# %% [markdown]
# ## architecture

# %%
vae = VariationalAutoencoder(
    input_dim = (28,28,1)
    , encoder_conv_filters = [32,64,64,64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    , z_dim = 2
    , r_loss_factor = 1000
)

if mode == 'build':
    vae.save(RUN_FOLDER)
else:
    vae.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
vae.encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# encoder_conv_0 (Conv2D)         (None, 28, 28, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 28, 28, 32)   0           encoder_conv_0[0][0]
# __________________________________________________________________________________________________
# encoder_conv_1 (Conv2D)         (None, 14, 14, 64)   18496       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 14, 14, 64)   0           encoder_conv_1[0][0]
# __________________________________________________________________________________________________
# encoder_conv_2 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 7, 7, 64)     0           encoder_conv_2[0][0]
# __________________________________________________________________________________________________
# encoder_conv_3 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 7, 7, 64)     0           encoder_conv_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3136)         0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# mu (Dense)                      (None, 2)            6274        flatten[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 2)            6274        flatten[0][0]
# __________________________________________________________________________________________________
# encoder_output (Sampling)       (None, 2)            0           mu[0][0]
#                                                                  log_var[0][0]
# ==================================================================================================
# Total params: 105,220
# Trainable params: 105,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
vae.decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 2)]               0
# _________________________________________________________________
# dense (Dense)                (None, 3136)              9408
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_0 (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_1 (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# decoder_conv_t_2 (Conv2DTran (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# decoder_conv_t_3 (Conv2DTran (None, 28, 28, 1)         289
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## training

# %%
LEARNING_RATE = 0.0005

# %%
vae.compile(LEARNING_RATE)

# %%
BATCH_SIZE = 32
EPOCHS = 50
PRINT_EVERY_N_BATCHES = 100
INITIAL_EPOCH = 0

# %%
vae.train(     
    x_train
    , batch_size = BATCH_SIZE
    , epochs = EPOCHS
    , run_folder = RUN_FOLDER
    , print_every_n_batches = PRINT_EVERY_N_BATCHES
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# Epoch 1/50
#    2/1875 [..............................] - ETA: 4:19 - loss: 229.5530 - reconstruction_loss: 229.5514 - kl_loss: 0.0016 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0050s vs `on_train_batch_end` time: 0.0239s). Check your callbacks.
# 1875/1875 [==============================] - 15s 7ms/step - loss: 58.2909 - reconstruction_loss: 55.0611 - kl_loss: 3.2298
#
# Epoch 00001: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00001: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 2/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 51.9842 - reconstruction_loss: 48.1313 - kl_loss: 3.8528
#
# Epoch 00002: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00002: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 3/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 50.5772 - reconstruction_loss: 46.4346 - kl_loss: 4.1426
#
# Epoch 00003: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00003: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 4/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 49.6271 - reconstruction_loss: 45.2824 - kl_loss: 4.3447
#
# Epoch 00004: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00004: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 5/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 48.9314 - reconstruction_loss: 44.4515 - kl_loss: 4.4799
#
# Epoch 00005: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00005: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 6/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 48.4503 - reconstruction_loss: 43.8658 - kl_loss: 4.5844
#
# Epoch 00006: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00006: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 7/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 48.0303 - reconstruction_loss: 43.3679 - kl_loss: 4.6624
#
# Epoch 00007: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00007: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 8/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 47.7575 - reconstruction_loss: 43.0204 - kl_loss: 4.7371
#
# Epoch 00008: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00008: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 9/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 47.4913 - reconstruction_loss: 42.7182 - kl_loss: 4.7730
#
# Epoch 00009: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00009: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 10/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 47.2937 - reconstruction_loss: 42.4625 - kl_loss: 4.8312
#
# Epoch 00010: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00010: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 11/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 47.0775 - reconstruction_loss: 42.2054 - kl_loss: 4.8721
#
# Epoch 00011: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00011: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 12/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 46.8992 - reconstruction_loss: 42.0001 - kl_loss: 4.8991
#
# Epoch 00012: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00012: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 13/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 46.7347 - reconstruction_loss: 41.8065 - kl_loss: 4.9282
#
# Epoch 00013: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00013: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 14/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 46.5740 - reconstruction_loss: 41.6175 - kl_loss: 4.9565
#
# Epoch 00014: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00014: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch
saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 33/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 45.0821 - reconstruction_loss: 39.8484 - kl_loss: 5.2337
#
# Epoch 00033: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00033: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 34/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 45.0815 - reconstruction_loss: 39.8356 - kl_loss: 5.2458
#
# Epoch 00034: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00034: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 35/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 45.0291 - reconstruction_loss: 39.7868 - kl_loss: 5.2423
#
# Epoch 00035: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00035: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 36/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 44.9816 - reconstruction_loss: 39.7308 - kl_loss: 5.2508
#
# Epoch 00036: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00036: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 37/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 44.9662 - reconstruction_loss: 39.6973 - kl_loss: 5.2689: 0s - loss: 44.9564 - reconstruction_loss: 39.6881 - kl_los
#
# Epoch 00037: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00037: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 38/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 44.9163 - reconstruction_loss: 39.6457 - kl_loss: 5.2706
#
# Epoch 00038: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00038: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 39/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 44.8569 - reconstruction_loss: 39.5890 - kl_loss: 5.2679
#
# Epoch 00039: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00039: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 40/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 44.8083 - reconstruction_loss: 39.5198 - kl_loss: 5.2885
#
# Epoch 00040: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00040: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 41/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 44.8026 - reconstruction_loss: 39.5168 - kl_loss: 5.2858
#
# Epoch 00041: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00041: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 42/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 44.7713 - reconstruction_loss: 39.4761 - kl_loss: 5.2951
#
# Epoch 00042: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00042: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 43/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 44.7423 - reconstruction_loss: 39.4438 - kl_loss: 5.2985
#
# Epoch 00043: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00043: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 44/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 44.7093 - reconstruction_loss: 39.4049 - kl_loss: 5.3044
#
# Epoch 00044: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00044: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 45/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 44.6919 - reconstruction_loss: 39.3692 - kl_loss: 5.3227
#
# Epoch 00045: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00045: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 46/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 44.6462 - reconstruction_loss: 39.3316 - kl_loss: 5.3146
#
# Epoch 00046: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00046: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 47/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 44.6303 - reconstruction_loss: 39.3120 - kl_loss: 5.3183
#
# Epoch 00047: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00047: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 48/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 44.5769 - reconstruction_loss: 39.2553 - kl_loss: 5.3216
#
# Epoch 00048: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00048: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 49/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 44.5698 - reconstruction_loss: 39.2493 - kl_loss: 5.3205
#
# Epoch 00049: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00049: saving model to run/vae/0002_digits\weights\weights.h5
# Epoch 50/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 44.5301 - reconstruction_loss: 39.1988 - kl_loss: 5.3313
#
# Epoch 00050: saving model to run/vae/0002_digits\weights\weights.h5
#
# Epoch 00050: saving model to run/vae/0002_digits\weights\weights.h5
